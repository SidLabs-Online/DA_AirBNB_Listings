# %% [markdown]
# <a href="https://colab.research.google.com/github/SidLabs-Online/DA_AirBNB_Listings/blob/main/DA_AirBNB_Listings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


raw_data = pd.read_csv("listings.csv")

raw_data.head(3)
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  27886  Romantic, stylish B&B houseboat in canal district    97647
#
#    host_name  neighbourhood_group                           neighbourhood  \
# 0     Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1  Alexander                  NaN                            Centrum-Oost
# 2       Flip                  NaN                            Centrum-West
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 0  52.36435    4.94358  Private room     49               3
# 1  52.36407    4.89393  Private room    106               1
# 2  52.38761    4.89188  Private room    136               2
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                305  2022-08-30               1.86
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6893 entries, 0 to 6892
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6893 non-null   int64
#  1   name                            6893 non-null   object
#  2   host_id                         6893 non-null   int64
#  3   host_name                       6893 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   6893 non-null   object
#  6   latitude                        6893 non-null   float64
#  7   longitude                       6893 non-null   float64
#  8   room_type                       6893 non-null   object
#  9   price                           6893 non-null   int64
#  10  minimum_nights                  6893 non-null   int64
#  11  number_of_reviews               6893 non-null   int64
# ...

# %%
raw_data.describe()
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  6.893000e+03  6.893000e+03                  0.0  6893.000000
# mean   1.039312e+17  9.626814e+07                  NaN    52.365961
# std    2.377222e+17  1.277327e+08                  NaN     0.022094
# min    2.818000e+03  3.159000e+03                  NaN    52.268010
# 25%    1.407934e+07  9.426449e+06                  NaN    52.355030
# 50%    3.110072e+07  3.338184e+07                  NaN    52.365870
# 75%    5.032563e+07  1.354875e+08                  NaN    52.377040
# max    7.099861e+17  4.783754e+08                  NaN    52.442340
#
#          longitude        price  minimum_nights  number_of_reviews  \
# count  6893.000000  6893.000000     6893.000000        6893.000000
# mean      4.892367   218.487306        5.180183          49.746700
# std       0.041864   192.576328       38.826489          97.005518
# min       4.742430     0.000000        1.000000           0.000000
# ...

# %%
raw_data['room_type'].value_counts()
# Out:
# Entire home/apt    4922
# Private room       1859
# Hotel room           75
# Shared room          37
# Name: room_type, dtype: int64

# %%
raw_data[['minimum_nights', 'availability_365', 'minimum_nights']].max()
# Out:
# minimum_nights      1001
# availability_365     365
# minimum_nights      1001
# dtype: int64

# %%
df1 = raw_data[['host_name', 'price', 'reviews_per_month', 'number_of_reviews_ltm', 'room_type']]
df1.head(3)
# Out:
#    host_name  price  reviews_per_month  number_of_reviews_ltm     room_type
# 0     Daniel     49               1.86                     25  Private room
# 1  Alexander    106               2.22                      0  Private room
# 2       Flip    136               1.78                      8  Private room

# %%
#df1.sort_values('number_of_reviews_ltm')
df1[['number_of_reviews_ltm', 'price', 'reviews_per_month']].max()
#df1[['number_of_reviews_ltm', 'price']].min()
# Out:
# number_of_reviews_ltm    1250.00
# price                    7900.00
# reviews_per_month         104.11
# dtype: float64

# %%
df2 = df1[df1['room_type'] == 'Private room']
df2.head()
# Out:
#    host_name  price  reviews_per_month  number_of_reviews_ltm     room_type
# 0     Daniel     49               1.86                     25  Private room
# 1  Alexander    106               2.22                      0  Private room
# 2       Flip    136               1.78                      8  Private room
# 3      Edwin     75               2.92                     75  Private room
# 4      Edwin     55               4.16                     86  Private room

# %%
df3 = df2[df2['number_of_reviews_ltm'] >= 315]
df3
# Out:
#                              host_name  price  reviews_per_month  \
# 4418  Conscious Hotel The Tire Station    240              49.85
# 4818                         Jean Paul    172             104.11
# 4830                         Jean Paul    183              27.61
#
#       number_of_reviews_ltm     room_type
# 4418                    762  Private room
# 4818                   1250  Private room
# 4830                    319  Private room

# %%
df4 = df3.sort_values(['number_of_reviews_ltm'], ascending=[False])
df4
# Out:
#                              host_name  price  reviews_per_month  \
# 4818                         Jean Paul    172             104.11
# 4418  Conscious Hotel The Tire Station    240              49.85
# 4830                         Jean Paul    183              27.61
#
#       number_of_reviews_ltm     room_type
# 4818                   1250  Private room
# 4418                    762  Private room
# 4830                    319  Private room

# %%
df4.describe()
# Out:
#             price  reviews_per_month  number_of_reviews_ltm
# count    3.000000           3.000000               3.000000
# mean   198.333333          60.523333             777.000000
# std     36.501142          39.351017             465.681221
# min    172.000000          27.610000             319.000000
# 25%    177.500000          38.730000             540.500000
# 50%    183.000000          49.850000             762.000000
# 75%    211.500000          76.980000            1006.000000
# max    240.000000         104.110000            1250.000000
